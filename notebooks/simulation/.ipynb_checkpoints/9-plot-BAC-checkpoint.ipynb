# %%
# %load_ext autoreload
# %autoreload 2
import sys, os
from os.path import expanduser
## actions required!!!!!!!!!!!!!!!!!!!! change your folder path 
path_repo = expanduser("~/Documents/G3_2/regime-identification"); sys.path.append(path_repo)
path_file = expanduser("~/data/G3_2/regime-identification/simulation")
path = {}
for folder in ["summary", "summary-cluster", "figure-paper"]:
    path[folder] = f"{path_file}/{folder}"

# %%
from regime.simulation_helper import *

# %%
# plotting
import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns
# mpl.style.use("seaborn-v0_8")
plt.rcParams['figure.figsize'] = [9, 9]
plt.rcParams['axes.titlesize'] = 20
plt.rcParams['axes.labelsize'] = 20
plt.rcParams['xtick.labelsize'] = 20
plt.rcParams['ytick.labelsize'] = 20
plt.rcParams['legend.fontsize'] = 20
plt.rcParams['font.size'] = 30
plt.rcParams['font.family'] = 'cmr10'
plt.rcParams['axes.formatter.use_mathtext'] = True

# %%
key_data = "2-state-daily"
n_s = 1000
key_feat = "zhengB"

# %%
key_data = "2-state-weekly"
n_s = 500
key_feat = "zhengB"

# %%
df = {}
for model in ["discrete", "cont", "cont-mode"]:
    df[model] = load_file(path, "summary-cluster", key_data, "means", n_s, key_feat, model, suffix="h5")

# %%
lambdas = generate_param_grid()["jump_penalty"]
# Out:
# [1.00000000e-02 1.00000000e-01 1.00000000e+00 1.00000000e+01
#  2.15443469e+01 4.64158883e+01 1.00000000e+02 2.15443469e+02
#  4.64158883e+02 1.00000000e+03 2.15443469e+03 4.64158883e+03
#  1.00000000e+04 1.00000000e+05 1.00000000e+06]

# %%
name_dict = dict(zip(["discrete", "cont", "cont-mode"], ["discrete", "continuous", "continuous w/ mode loss"]))

# %%
_, ax = plt.subplots(figsize = (16, 10))
for model in ["discrete", "cont", "cont-mode"]:
    ax.plot(lambdas, df[model].BAC, label=name_dict[model])
ax.set(xscale="log", ylabel="balanced accuracy", xlabel=r"$\lambda$", xticks=10**np.arange(-2, 5.1, .5), ylim=[.45, 1], title=f"length {n_s}")
ax.legend()
plt.savefig(f"{path['figure-paper']}/lambda-plot-new.jpeg", bbox_inches="tight")

# %%
_, ax = plt.subplots(figsize = (16, 10))
for model in ["discrete", "cont", "cont-mode"]:
    ax.plot(lambdas, df[model].BAC, label=name_dict[model])
ax.set(xscale="log", ylabel="balanced accuracy", xlabel=r"$\lambda$", xticks=10**np.arange(-2, 5.1, .5), ylim=[.45, 1], title=f"length {n_s}")
ax.legend()
# plt.savefig(f"{path['figure-paper']}/lambda_plot.jpeg", bbox_inches="tight")

# %%
df["discrete"]
# Out:
#      $\mu_1$   $\mu_2$  $\sigma_1$  $\sigma_2$  $\gamma_{12}$  $\gamma_{21}$  \
# 0   0.000716 -0.000971    0.007605    0.015558       0.048157       0.123615
# 1   0.000730 -0.000995    0.007621    0.015594       0.044671       0.117248
# 2   0.000685 -0.000947    0.007690    0.015735       0.027061       0.078453
# 3   0.000650 -0.000826    0.007821    0.015996       0.007912       0.029590
# 4   0.000617 -0.000786    0.007844    0.016041       0.004474       0.021943
# 5   0.000614 -0.000745    0.007852    0.016069       0.002543       0.017837
# 6   0.000596 -0.000679    0.007899    0.016263       0.001866       0.015433
# 7   0.000579 -0.000815    0.008035    0.017039       0.001333       0.012331
# 8   0.000534 -0.000894    0.008447    0.017122       0.000710       0.008298
# 9   0.000401 -0.000215    0.009676    0.014526       0.000000       0.000000
# 10  0.000401 -0.000215    0.009676    0.014526       0.000000       0.000000
# ...

# %%
x = np.arange(6)

# %%
_, ax = plt.subplots()
ax.plot(x, x)
